# %%
#Librerias utilizadas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Lectura del archivo de datos
df = pd.DataFrame( pd.read_csv("meteo-nogal-09.csv", engine="python" ) )
df.head(20)
# Out:
#         DATE   TIME  Unnamed: 2  Unnamed: 3      u_Avg      v_Avg  \
# 0         TS    NaN         NaN         NaN        m/s        m/s
# 1   01-01-09  00:10         1.0         NaN      1.215      0.506
# 2   01-01-09  00:20         1.0         NaN      0.892      0.588
# 3   01-01-09  00:30         1.0         NaN      1.227  0.6850001
# 4   01-01-09  00:40         1.0         NaN      1.135  0.7410001
# 5   01-01-09  00:50         1.0         NaN  0.7550001      1.064
# 6   01-01-09  01:00         1.0         NaN  0.8850001      0.992
# 7   01-01-09  01:10         1.0         NaN      0.611  0.7270001
# 8   01-01-09  01:20         1.0         NaN       0.33      0.886
# 9   01-01-09  01:30         1.0         NaN      0.118      1.321
# 10  01-01-09  01:40         1.0         NaN      0.056      1.315
# 11  01-01-09  01:50         1.0         NaN      0.327      1.287
# 12  01-01-09  02:00         1.0         NaN  0.7550001      1.193
# ...

# %%
df.dtypes
# Out:
# DATE            object
# TIME            object
# Unnamed: 2     float64
# Unnamed: 3     float64
# u_Avg           object
# v_Avg           object
# w_Avg           object
# t_Avg           object
# kh20_Avg        object
# net_rad_Avg     object
# shf1_Avg        object
# shf2_Avg        object
# vv_Avg          object
# airT_Avg        object
# rh_Avg         float64
# e_sat_Avg       object
# e_Avg           object
# h2o_hmp_Avg     object
# Unnamed: 18    float64
# Unnamed: 19     object
# Unnamed: 20     object
# Unnamed: 21    float64
# Unnamed: 22     object
# Unnamed: 23     object
# Unnamed: 24     object
# Unnamed: 25     object
# Unnamed: 26     object
# Unnamed: 27     object
# Unnamed: 28     object
# Unnamed: 29     object
# Unnamed: 30     object
# Unnamed: 31     object
# Unnamed: 32     object
# Unnamed: 33     object
# Unnamed: 34     object
# Unnamed: 35     object
# dtype: object

# %%
#Se toman las columnas relevantes para el análisis
#df0 = df.filter( items=["DATE ","TIME","u_Avg","v_Avg","w_Avg","t_Avg","kh20_Avg ","net_rad_Avg","shf1_Avg ","shf2_Avg ","vv_Avg","airT_Avg","rh_Avg","e_sat_Avg","e_Avg","h2o_hmp_Avg"], axis=1)

#Se eliminan las columnas innecesarias para el análisis (Unnamed)
df.drop( df.columns[18:36], axis=1, inplace=True )
df.drop( df.columns[2:4], axis=1, inplace=True )
df.head()
# Out:
#        DATE   TIME  u_Avg      v_Avg        w_Avg  t_Avg kh20_Avg net_rad_Avg  \
# 0        TS    NaN    m/s        m/s          m/s   degC       mV        w/m2
# 1  01-01-09  00:10  1.215      0.506       -0.044  10.95    1.159      -176.5
# 2  01-01-09  00:20  0.892      0.588       -0.072  10.81    1.159      -176.6
# 3  01-01-09  00:30  1.227  0.6850001  -0.06900001  10.34    1.224      -175.5
# 4  01-01-09  00:40  1.135  0.7410001       -0.093    9.8    1.258      -182.7
#
#   shf1_Avg shf2_Avg vv_Avg  airT_Avg  rh_Avg e_sat_Avg  e_Avg h2o_hmp_Avg
# 0     w/m2     w/m2    m/s      degC     NaN       kPa    kPa        g/m3
# 1    23.58   -26.72  1.327       9.4   0.899     1.178  1.059        8.12
# 2    23.73   -26.76  1.079      9.24   0.896     1.166  1.045        8.02
# 3    23.61   -26.46  1.421  9.059999   0.896     1.152  1.032    7.926001
# 4    23.41   -26.46  1.384  9.059999   0.874     1.152  1.008       7.737

# %%
#Se crea una nueva columna "FECHA" a partir de las columnas "DATE" y "TIME"
df["FECHA"] = df["DATE"] + " "+ df["TIME"]
#Se eliminan las columnas "DATE" y "TIME"
df.drop( ["DATE","TIME"], axis=1, inplace=True )
df.head()
# Out:
#    u_Avg      v_Avg        w_Avg  t_Avg kh20_Avg net_rad_Avg shf1_Avg  \
# 0    m/s        m/s          m/s   degC       mV        w/m2     w/m2
# 1  1.215      0.506       -0.044  10.95    1.159      -176.5    23.58
# 2  0.892      0.588       -0.072  10.81    1.159      -176.6    23.73
# 3  1.227  0.6850001  -0.06900001  10.34    1.224      -175.5    23.61
# 4  1.135  0.7410001       -0.093    9.8    1.258      -182.7    23.41
#
#   shf2_Avg vv_Avg  airT_Avg  rh_Avg e_sat_Avg  e_Avg h2o_hmp_Avg  \
# 0     w/m2    m/s      degC     NaN       kPa    kPa        g/m3
# 1   -26.72  1.327       9.4   0.899     1.178  1.059        8.12
# 2   -26.76  1.079      9.24   0.896     1.166  1.045        8.02
# 3   -26.46  1.421  9.059999   0.896     1.152  1.032    7.926001
# 4   -26.46  1.384  9.059999   0.874     1.152  1.008       7.737
#
#             FECHA
# 0             NaN
# 1  01-01-09 00:10
# 2  01-01-09 00:20
# 3  01-01-09 00:30
# 4  01-01-09 00:40

# %%
#Se elimina el 1er renglón, que contiene las unidades en las que se miden las variables
df = df.drop(df.index[0]).reset_index(drop=True)
df.head()
# Out:
#        u_Avg      v_Avg        w_Avg  t_Avg kh20_Avg net_rad_Avg shf1_Avg  \
# 0      1.215      0.506       -0.044  10.95    1.159      -176.5    23.58
# 1      0.892      0.588       -0.072  10.81    1.159      -176.6    23.73
# 2      1.227  0.6850001  -0.06900001  10.34    1.224      -175.5    23.61
# 3      1.135  0.7410001       -0.093    9.8    1.258      -182.7    23.41
# 4  0.7550001      1.064       -0.149   8.87    1.332      -184.8    23.22
#
#   shf2_Avg vv_Avg  airT_Avg  rh_Avg e_sat_Avg  e_Avg h2o_hmp_Avg  \
# 0   -26.72  1.327       9.4   0.899     1.178  1.059        8.12
# 1   -26.76  1.079      9.24   0.896     1.166  1.045        8.02
# 2   -26.46  1.421  9.059999   0.896     1.152  1.032    7.926001
# 3   -26.46  1.384  9.059999   0.874     1.152  1.008       7.737
# 4   -26.39  1.359      8.63   0.859     1.119  0.961        7.39
#
#             FECHA
# 0  01-01-09 00:10
# 1  01-01-09 00:20
# 2  01-01-09 00:30
# 3  01-01-09 00:40
# 4  01-01-09 00:50

# %%
df.dtypes
# Out:
# u_Avg           object
# v_Avg           object
# w_Avg           object
# t_Avg           object
# kh20_Avg        object
# net_rad_Avg     object
# shf1_Avg        object
# shf2_Avg        object
# vv_Avg          object
# airT_Avg        object
# rh_Avg         float64
# e_sat_Avg       object
# e_Avg           object
# h2o_hmp_Avg     object
# FECHA           object
# dtype: object

# %%
#Se convierten las variables de object a float64
df[df.columns[0:14]] = df[df.columns[0:14]].apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# u_Avg          float64
# v_Avg          float64
# w_Avg          float64
# t_Avg          float64
# kh20_Avg       float64
# net_rad_Avg    float64
# shf1_Avg       float64
# shf2_Avg       float64
# vv_Avg         float64
# airT_Avg       float64
# rh_Avg         float64
# e_sat_Avg      float64
# e_Avg          float64
# h2o_hmp_Avg    float64
# FECHA           object
# dtype: object

# %%
#Se utiliza la funcion corr() para hallar correlaciones entre las variables
df1 = df.corr(method='pearson', min_periods=1)
#Se muestra la matriz de correlación
df1.head(14)
# Out:
#                 u_Avg     v_Avg     w_Avg     t_Avg  kh20_Avg  net_rad_Avg  \
# u_Avg        1.000000  0.241773  0.028537  0.058863 -0.047981    -0.093187
# v_Avg        0.241773  1.000000  0.016387  0.019921  0.153061    -0.116671
# w_Avg        0.028537  0.016387  1.000000  0.667294  0.121010     0.044286
# t_Avg        0.058863  0.019921  0.667294  1.000000 -0.002184     0.064174
# kh20_Avg    -0.047981  0.153061  0.121010 -0.002184  1.000000    -0.157635
# net_rad_Avg -0.093187 -0.116671  0.044286  0.064174 -0.157635     1.000000
# shf1_Avg     0.089411  0.029321 -0.079466 -0.094414 -0.005268    -0.206065
# shf2_Avg     0.003093 -0.053957 -0.011563 -0.008491 -0.058466    -0.027180
# vv_Avg      -0.138616 -0.075175  0.923685  0.593997  0.149991     0.156017
# airT_Avg    -0.363807 -0.341920 -0.374504 -0.288852 -0.116329     0.326684
# rh_Avg       0.326205  0.099303  0.760058  0.433942  0.031765    -0.254705
# ...

# %%
#Heatmap hecho con Seaborn
hm_sb = sb.heatmap( df1 )
#Guardar imagen
fig = hm_sb.get_figure()
fig.savefig('hetmap-seaborn.png')

# %%
#Heatmap hecho con Matplotlib, usando la función pcolor()
plt.pcolor(df1)
plt.yticks(np.arange(0.5, len(df1.index), 1), df1.index)
plt.xticks(np.arange(0.5, len(df1.columns), 1), df1.columns)
plt.colorbar()

plt.title('Mapa de correlaciones')
plt.savefig('heatmap-matplotlib',plt=2000)
plt.show()

# %%
#Heatmap hecho con Matplotlib, usando la función coolwarm
from matplotlib import cm

fig, ax = plt.subplots()

cax = ax.imshow(df1, interpolation='nearest', cmap = cm.coolwarm)
ax.set_title('Mapa de correlaciones')

# Add colorbar, make sure to specify tick locations to match desired ticklabels
cbar = fig.colorbar(cax, ticks=[-1, 0, 1])

cbar.ax.set_yticklabels(['-1', '0', ' 1'])  # vertically oriented colorbar

plt.savefig('heatmap-matplotlib2', plt=2000)

# %%
#Scatterplot para las variables donde abs(corr) > 0.5
#df1[ df1[i,j] > 0.5 ]

# Set style of scatterplot
sb.set_context("notebook", font_scale=1.1)
sb.set_style("ticks")

# Create scatterplot of dataframe
sb.lmplot('u_Avg', # Horizontal axis
           'v_Avg', # Vertical axis
           data=df1, # Data source
           fit_reg=False, # Don't fix a regression line
#           hue="red", # Set color
           scatter_kws={"marker": "D", # Set marker style
                        "s": 100}) # S marker size

# Set title
plt.title('Histograma u_Avg vs v_Avg')

# Set x-axis label
plt.xlabel('u_Avg')

# Set y-axis label
plt.ylabel('v_Avg')
# Out:
# Text(3.2560000000000002, 0.5, 'v_Avg')

# %%
df1.plot.scatter(df1.columns, df1.index, c=df1, colormap='viridis')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('u_Avg', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4231             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4232                 colors = mcolors.to_rgba_array(c)
#    4233                 n_elem = colors.shape[0]
#
# ...

# %%
df2 = pd.DataFrame()

df2["Variable1"] = df1.columns 
df2["Variable2"] = df1.index

df2.head(15)

# %%
correlacion=[]

for i in range( 0, len(df1.index) )
    for j in range( i, len(df1.index) )
        
        if i==j
        Correlación[i] = 1
        
        elif i!=j
        Correlación[i] = df1.iloc[[i],[j]]
        
df2["Correlación"] = correlacion

# %%
df1.head(14)
# Out:
#                 u_Avg     v_Avg     w_Avg     t_Avg  kh20_Avg  net_rad_Avg  \
# u_Avg        1.000000  0.241773  0.028537  0.058863 -0.047981    -0.093187
# v_Avg        0.241773  1.000000  0.016387  0.019921  0.153061    -0.116671
# w_Avg        0.028537  0.016387  1.000000  0.667294  0.121010     0.044286
# t_Avg        0.058863  0.019921  0.667294  1.000000 -0.002184     0.064174
# kh20_Avg    -0.047981  0.153061  0.121010 -0.002184  1.000000    -0.157635
# net_rad_Avg -0.093187 -0.116671  0.044286  0.064174 -0.157635     1.000000
# shf1_Avg     0.089411  0.029321 -0.079466 -0.094414 -0.005268    -0.206065
# shf2_Avg     0.003093 -0.053957 -0.011563 -0.008491 -0.058466    -0.027180
# vv_Avg      -0.138616 -0.075175  0.923685  0.593997  0.149991     0.156017
# airT_Avg    -0.363807 -0.341920 -0.374504 -0.288852 -0.116329     0.326684
# rh_Avg       0.326205  0.099303  0.760058  0.433942  0.031765    -0.254705
# ...

# %%
#Lo siguiente es graficar cada caso donde se cumpla que abs(corr) > 0.6
#Los casos donde se cumple son:
#t_Avg - w_Avg
#vv_Avg - w_Avg
#rh_Avg - w_Avg
#rh_Avg - vv_Avg
#e_sat_Avg - airT_Avg
#e_Avg - w_Avg
#e_Avg - rh_Avg
#h2o_hmp_Avg - e_Avg
print(" ")

# %%
#t_Avg - w_Avg
sb_plot = sb.scatterplot( x=df['t_Avg'], y=df['w_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion1",plt=2000)

# %%
#vv_Avg - w_Avg
sb_plot = sb.scatterplot( x=df['vv_Avg'], y=df['w_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion2",plt=2000)

# %%
#rh_Avg - w_Avg
sb_plot = sb.scatterplot( x=df['rh_Avg'], y=df['w_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion3",plt=2000)

# %%
#rh_Avg - vv_Avg
sb_plot = sb.scatterplot( x=df['rh_Avg'], y=df['vv_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion4",plt=2000)

# %%
#e_sat_Avg - airT_Avg
sb_plot = sb.scatterplot( x=df['e_sat_Avg'], y=df['airT_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion5",plt=2000)

# %%
#e_Avg - w_Avg
sb_plot = sb.scatterplot( x=df['e_Avg'], y=df['w_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion6",plt=2000)

# %%
#e_Avg - rh_Avg
sb_plot = sb.scatterplot( x=df['e_Avg'], y=df['rh_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion7",plt=2000)

# %%
#h2o_hmp_Avg - e_Avg
sb_plot = sb.scatterplot( x=df['h2o_hmp_Avg'], y=df['e_Avg'] )
fig = sb_plot.get_figure()
fig.savefig("correlacion8",plt=2000)
